# %%
def reverse_string(s):
    reversed_str = ""
    for char in s:
        reversed_str = char + reversed_str
    return reversed_str

# Example usage
input_string = "Hello, World!"
reversed_string = reverse_string(input_string)
print("Original string:", input_string)
print("Reversed string:", reversed_string)

# Alternative approach

str1 = "Analytics Vidhya"
str2 = ""
for i in str1:
    str2 = i + str2
print("The original string is: 
,
The reversed string is: 

: 
,
: {
: 
,
: 

: [
,
") == "", "Empty string should return empty string"
assert reverse_string("a") == "a", "Single character should return itself"
assert reverse_string("abc") == "cba", "Should reverse 'abc' to 'cba'"
assert reverse_string("racecar") == "racecar", "Palindrome should return itself"
assert reverse_string("12345") == "54321", "Should reverse numbers as string"
print("All test cases passed for reverse_string!")

# %%
# Reverse a number
num = 1234
temp = num
reverse = 0
while num > 0:
    remainder = num % 10
    reverse = (reverse * 10) + remainder
    num = num // 10

print(reverse)
